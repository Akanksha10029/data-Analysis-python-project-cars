# %% [markdown]
# #Working on Real Project with Python - Data Analysis with Cars Dataset

# %% [markdown]
# **We are going to analyse data set pf cars using pandas dataframe**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/project-2 data analysis cars dataset.csv')
df.head(45)
# Out:
#      Make                             Model    Type  Origin DriveTrain  \
# 0   Acura                               MDX     SUV    Asia        All
# 1   Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2   Acura                           TSX 4dr   Sedan    Asia      Front
# 3   Acura                            TL 4dr   Sedan    Asia      Front
# 4   Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5   Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6   Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7    Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8    Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9    Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10   Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11   Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# ...

# %% [markdown]
# **Data cleaning**
#
#
# > Find the null values in the data set.If there is any null value in any column then, fill it with the mean of that column

# %%
df.shape
# Out:
# (432, 15)

# %%
df.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
df = df.dropna(axis=0)
df.head(35)
# Out:
#      Make                             Model    Type  Origin DriveTrain  \
# 0   Acura                               MDX     SUV    Asia        All
# 1   Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2   Acura                           TSX 4dr   Sedan    Asia      Front
# 3   Acura                            TL 4dr   Sedan    Asia      Front
# 4   Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5   Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6   Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7    Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8    Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9    Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10   Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11   Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# ...

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.shape
# Out:
# (426, 15)

# %% [markdown]
# **Check what are the differnt types of Make are there in our dataset and what is the count (occurance) of each Make in the data**

# %%
df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %%
df['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mazda             9
# Mercury           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# **Filtering**
#
#
# > **show all the record where origins are USA and Europe**

# %%
df[df['Origin'].isin(['USA','Europe'])].iloc[25:60:2]
# Out:
#          Make                    Model    Type  Origin DriveTrain      MSRP  \
# 33        BMW                 330i 4dr   Sedan  Europe       Rear  $35,495
# 35        BMW                330xi 4dr   Sedan  Europe        All  $37,245
# 37        BMW    330Ci convertible 2dr   Sedan  Europe       Rear  $44,295
# 40        BMW                545iA 4dr   Sedan  Europe       Rear  $54,995
# 42        BMW                745Li 4dr   Sedan  Europe       Rear  $73,195
# 44        BMW       M3 convertible 2dr  Sports  Europe       Rear  $56,595
# 46        BMW  Z4 convertible 3.0i 2dr  Sports  Europe       Rear  $41,045
# 48      Buick                  Rainier     SUV     USA        All  $37,895
# 50      Buick       Century Custom 4dr   Sedan     USA      Front  $22,180
# 52      Buick             Regal LS 4dr   Sedan     USA      Front  $24,895
# 54      Buick      LeSabre Limited 4dr   Sedan     USA      Front  $32,245
# ...

# %% [markdown]
# **Removing unwanted records from the dataset**
#
#
# > like Remove all the records(rows) where weight is more than 4000

# %%
df[df['Weight']<5000]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
df[~(df['Weight']<5000)]
# Out:
#               Make                  Model   Type  Origin DriveTrain      MSRP  \
# 57        Cadillac               Escalade    SUV     USA      Front  $52,795
# 64        Cadillac           Escalade EXT  Truck     USA        All  $52,975
# 66       Chevrolet               Tahoe LT    SUV     USA        All  $41,465
# 86       Chevrolet         Avalanche 1500  Truck     USA        All  $36,100
# 120           Ford      Excursion 6.8 XLT    SUV     USA        All  $41,475
# 121           Ford     Expedition 4.6 XLT    SUV     USA      Front  $34,560
# 139           Ford  F-150 Supercab Lariat  Truck     USA        All  $33,540
# 144            GMC         Yukon 1500 SLE    SUV     USA      Front  $35,725
# 145            GMC      Yukon XL 2500 SLT    SUV     USA        All  $46,265
# 149            GMC         Sierra HD 2500  Truck     USA        All  $29,322
# 169         Hummer                     H2    SUV     USA        All  $49,995
# ...

# %%
df.shape
# Out:
# (426, 15)

# %%
426 - 404 #22 rows like it has given us above
# Out:
# 22

# %% [markdown]
# **Applying function on a coloumn: In this if we want to make a change in any column value then we use apply function**
#
#
# > **Increase all the values of MPG_Highway by 5 values**

# %%
df['MPG_Highway'] = df['MPG_Highway'].apply(lambda x:x+5)
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...
